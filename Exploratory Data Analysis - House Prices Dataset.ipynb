# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\Loges\Downloads\Datasets\HousePrices.csv")
data
# Out:
#        Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 0       1          60         RL         65.0     8450      Pave   NaN
# 1       2          20         RL         80.0     9600      Pave   NaN
# 2       3          60         RL         68.0    11250      Pave   NaN
# 3       4          70         RL         60.0     9550      Pave   NaN
# 4       5          60         RL         84.0    14260      Pave   NaN
# ...   ...         ...        ...          ...      ...       ...   ...
# 2068  942          60         RL          NaN     8755      Pave   NaN
# 2069  943          90         RL         63.0     7711      Pave   NaN
# 2070  944          90         RL        313.0    25000      Pave   NaN
# 2071  945          20         RL         52.0    14375      Pave   NaN
# 2072  946          50         RM         98.0     8820      Pave   NaN
#
#      Property_Shape LandContour Utilities  ... PoolArea PoolQC  Fence  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 81 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2073 non-null   int64
#  1   Dwell_Type           2073 non-null   int64
#  2   Zone_Class           2073 non-null   object
#  3   LotFrontage          1753 non-null   float64
#  4   LotArea              2073 non-null   int64
#  5   Road_Type            2073 non-null   object
#  6   Alley                129 non-null    object
#  7   Property_Shape       2073 non-null   object
#  8   LandContour          2073 non-null   object
#  9   Utilities            2073 non-null   object
#  10  LotConfig            2073 non-null   object
#  11  LandSlope            2073 non-null   object
#  12  Neighborhood         2073 non-null   object
#  13  Condition1           2073 non-null   object
#  14  Condition2           2073 non-null   object
# ...

# %%
data['YrSold'].unique()
# Out:
# array([2008, 2007, 2006, 2009, 2010], dtype=int64)

# %%
data.describe()
# Out:
#                 Id   Dwell_Type  LotFrontage        LotArea  OverallQual  \
# count  2073.000000  2073.000000  1753.000000    2073.000000  2073.000000
# mean    916.132176    60.556199    72.056475   10717.853353     6.233478
# std     493.014670   159.924810    27.987475    9215.982306     1.517115
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     519.000000    20.000000    60.000000    7620.000000     5.000000
# 50%     932.000000    50.000000    70.000000    9492.000000     6.000000
# 75%    1302.000000    70.000000    83.000000   11601.000000     7.000000
# max    1820.000000  7080.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  2073.000000  2073.000000   2073.000000  2059.000000  2073.000000  ...
# mean      5.835022  1969.445731   1986.617463   101.875668   437.949349  ...
# std       1.360214    30.222647     20.432694   179.169217   448.051119  ...
# ...

# %%
data.corr()
# Out:
#                            Id  Dwell_Type  LotFrontage   LotArea  OverallQual  \
# Id                   1.000000    0.043264     0.066902  0.004201     0.083367
# Dwell_Type           0.043264    1.000000    -0.075636 -0.033609     0.046278
# LotFrontage          0.066902   -0.075636     1.000000  0.311156     0.108095
# LotArea              0.004201   -0.033609     0.311156  1.000000     0.078232
# OverallQual          0.083367    0.046278     0.108095  0.078232     1.000000
# OverallCond          0.195635    0.033023    -0.011213  0.014209    -0.010092
# YearBuilt           -0.080204    0.027194     0.092680 -0.010551     0.335326
# YearRemodAdd         0.087397    0.042864     0.101034  0.017766     0.379579
# MasVnrArea          -0.027147   -0.004832     0.129620  0.064370     0.283981
# BsmtFinSF1          -0.016424   -0.034072     0.139424  0.164989     0.163501
# BsmtFinSF2           0.004953   -0.025699     0.062472  0.075875    -0.058146
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(30,20))
columns=["Property_Shape","BedroomAbvGr","Electrical","CentralAir",
         "GarageType","Alley","Heating","SaleType",
         "SaleCondition","Foundation","KitchenQual","HouseStyle",
        "OverallQual","MasVnrType","YrSold"]
collen=len(columns)//4
if(len(columns)%4!=0):
    collen+=1
for i in range(len(columns)):
    plt.subplot(collen,4,i+1)
    sns.countplot(x=columns[i],data=data)

plt.show()

# %%
plt.figure(figsize=(30,20))

columns=["Neighborhood","RoofStyle","HouseStyle",
         "SaleCondition","Zone_Class","PavedDrive",
        "GarageType","LandSlope","Fence",
        "Fireplaces","FullBath","HalfBath"]
collen=len(columns)//3
if(len(columns)%3!=0):
    collen+=1
for i in range(len(columns)):
    plt.subplot(collen,3,i+1)
    height=data[columns[i]].value_counts()
    plt.pie(height, labels=height.index)
    plt.title(columns[i])

plt.show()

# %%
plt.figure(figsize=(30,20))

columns=['Property_Sale_Price','YearBuilt','LotArea',
        'MasVnrArea',"PoolArea","GarageArea",
         '1stFlrSF','2ndFlrSF',"TotalBsmtSF"]
collen=len(columns)//3
if len(columns)%3!=0:
    collen+=1

for i in range(len(columns)):
    plt.subplot(collen,3,i+1)
    plt.hist(data[columns[i]])
    plt.xlabel(columns[i])
    plt.ylabel("No. of Houses")

plt.show()

# %%
plt.figure(figsize=(20,10))
columns=['LotArea','Property_Sale_Price',"Dwell_Type","YearBuilt",
         "OverallQual","PoolArea","GarageArea",
         '1stFlrSF','2ndFlrSF',"TotalBsmtSF"]
j=0
for i in columns:
    plt.subplot(2,len(columns)//2,j+1)
    plt.boxplot(data[i])
    plt.xlabel(i)
    j+=1
plt.show()

# %%
count=data.isnull().sum()
for col in count.index:
    if count[col]>0 and data.dtypes[col]=='object':
        print(col,count[col],data[col].unique(),sep=' : ')
# Out:
# Alley : 1944 : [nan 'Grvl' 'Pave']
# MasVnrType : 14 : ['BrkFace' 'None' 'Stone' 'BrkCmn' nan]
# BsmtQual : 59 : ['Gd' 'TA' 'Ex' nan 'Fa']
# BsmtCond : 59 : ['TA' 'Gd' nan 'Fa' 'Po']
# BsmtExposure : 61 : ['No' 'Gd' 'Mn' 'Av' nan]
# BsmtFinType1 : 59 : ['GLQ' 'ALQ' 'Unf' 'Rec' 'BLQ' nan 'LwQ']
# BsmtFinType2 : 60 : ['Unf' 'BLQ' nan 'ALQ' 'Rec' 'LwQ' 'GLQ']
# Electrical : 1 : ['SBrkr' 'FuseF' 'FuseA' 'FuseP' 'Mix' nan]
# FireplaceQu : 988 : [nan 'TA' 'Gd' 'Fa' 'Ex' 'Po']
# GarageType : 113 : ['Attchd' 'Detchd' 'BuiltIn' 'CarPort' nan 'Basment' '2Types']
# GarageFinish : 113 : ['RFn' 'Unf' 'Fin' nan]
# GarageQual : 113 : ['TA' 'Fa' 'Gd' nan 'Ex' 'Po']
# GarageCond : 113 : ['TA' 'Fa' nan 'Gd' 'Po' 'Ex']
# PoolQC : 2065 : [nan 'Ex' 'Fa' 'Gd']
# Fence : 1669 : [nan 'MnPrv' 'GdWo' 'GdPrv' 'MnWw']
# MiscFeature : 1993 : [nan 'Shed' 'Gar2' 'Othr' 'TenC']

# %%
# data=data.drop(["Alley","FireplaceQu","PoolQC","Fence","MiscFeature"],axis=1)

# %%
for i in data.dtypes.index:
    if data.dtypes[i]=='object':
        lst=data[i].unique()
        print(i,lst,sep=' : ')
# Out:
# Zone_Class : ['RL' 'RM' 'C (all)' 'FV' 'RH']
# Road_Type : ['Pave' 'Grvl']
# Alley : [nan 'Grvl' 'Pave']
# Property_Shape : ['Reg' 'IR1' 'IR2' 'IR3']
# LandContour : ['Lvl' 'Bnk' 'Low' 'HLS']
# Utilities : ['AllPub' 'NoSeWa']
# LotConfig : ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
# LandSlope : ['Gtl' 'Mod' 'Sev']
# Neighborhood : ['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'NAmes' 'SawyerW' 'IDOTRR'
#  'MeadowV' 'Edwards' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'NPkVill'
#  'Blmngtn' 'BrDale' 'SWISU' 'Blueste']
# Condition1 : ['Norm' 'Feedr' 'PosN' 'Artery' 'RRAe' 'RRNn' 'RRAn' 'PosA' 'RRNe']
# Condition2 : ['Norm' 'Artery' 'RRNn' 'Feedr' 'PosN' 'PosA' 'RRAn' 'RRAe']
# Dwelling_Type : ['1Fam' '2fmCon' 'Duplex' 'TwnhsE' 'Twnhs']
# HouseStyle : ['2Story' '1Story' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin']
# RoofStyle : ['Gable' 'Hip' 'Gambrel' 'Mansard' 'Flat' 'Shed']
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
encodings={}
for i in data.dtypes.index:
    if data.dtypes[i]=='object':
        data[i]=encoder.fit_transform(data[i])
        encodings[i]=encoder.classes_.copy()
for col in encodings:
    print(col,encodings[col],sep=' : ')
# Out:
# Zone_Class : ['C (all)' 'FV' 'RH' 'RL' 'RM']
# Road_Type : ['Grvl' 'Pave']
# Alley : ['Grvl' 'Pave' nan]
# Property_Shape : ['IR1' 'IR2' 'IR3' 'Reg']
# LandContour : ['Bnk' 'HLS' 'Low' 'Lvl']
# Utilities : ['AllPub' 'NoSeWa']
# LotConfig : ['Corner' 'CulDSac' 'FR2' 'FR3' 'Inside']
# LandSlope : ['Gtl' 'Mod' 'Sev']
# Neighborhood : ['Blmngtn' 'Blueste' 'BrDale' 'BrkSide' 'ClearCr' 'CollgCr' 'Crawfor'
#  'Edwards' 'Gilbert' 'IDOTRR' 'MeadowV' 'Mitchel' 'NAmes' 'NPkVill'
#  'NWAmes' 'NoRidge' 'NridgHt' 'OldTown' 'SWISU' 'Sawyer' 'SawyerW'
#  'Somerst' 'StoneBr' 'Timber' 'Veenker']
# Condition1 : ['Artery' 'Feedr' 'Norm' 'PosA' 'PosN' 'RRAe' 'RRAn' 'RRNe' 'RRNn']
# Condition2 : ['Artery' 'Feedr' 'Norm' 'PosA' 'PosN' 'RRAe' 'RRAn' 'RRNn']
# Dwelling_Type : ['1Fam' '2fmCon' 'Duplex' 'Twnhs' 'TwnhsE']
# HouseStyle : ['1.5Fin' '1.5Unf' '1Story' '2.5Fin' '2.5Unf' '2Story' 'SFoyer' 'SLvl']
# RoofStyle : ['Flat' 'Gable' 'Gambrel' 'Hip' 'Mansard' 'Shed']
# ...

# %%
data
# Out:
#        Id  Dwell_Type  Zone_Class  LotFrontage  LotArea  Road_Type  Alley  \
# 0       1          60           3         65.0     8450          1      2
# 1       2          20           3         80.0     9600          1      2
# 2       3          60           3         68.0    11250          1      2
# 3       4          70           3         60.0     9550          1      2
# 4       5          60           3         84.0    14260          1      2
# ...   ...         ...         ...          ...      ...        ...    ...
# 2068  942          60           3          NaN     8755          1      2
# 2069  943          90           3         63.0     7711          1      2
# 2070  944          90           3        313.0    25000          1      2
# 2071  945          20           3         52.0    14375          1      2
# 2072  946          50           4         98.0     8820          1      2
#
#       Property_Shape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 81 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2073 non-null   int64
#  1   Dwell_Type           2073 non-null   int64
#  2   Zone_Class           2073 non-null   int32
#  3   LotFrontage          1753 non-null   float64
#  4   LotArea              2073 non-null   int64
#  5   Road_Type            2073 non-null   int32
#  6   Alley                2073 non-null   int32
#  7   Property_Shape       2073 non-null   int32
#  8   LandContour          2073 non-null   int32
#  9   Utilities            2073 non-null   int32
#  10  LotConfig            2073 non-null   int32
#  11  LandSlope            2073 non-null   int32
#  12  Neighborhood         2073 non-null   int32
#  13  Condition1           2073 non-null   int32
#  14  Condition2           2073 non-null   int32
# ...

# %%
count=data.isnull().sum()
for ind in count.index:
    if count[ind]>0:
        print(ind, count[ind])
# Out:
# LotFrontage 320
# MasVnrArea 14
# GarageYrBlt 113

# %%
help(sns.countplot)
# Out:
# Help on function countplot in module seaborn.categorical:
#
# countplot(*, x=None, y=None, hue=None, data=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, dodge=True, ax=None, **kwargs)
#     Show the counts of observations in each categorical bin using bars.
#
#     A count plot can be thought of as a histogram across a categorical, instead
#     of quantitative, variable. The basic API and options are identical to those
#     for :func:`barplot`, so you can compare counts across nested variables.
#
#
#     Input data can be passed in a variety of formats, including:
#
#     - Vectors of data represented as lists, numpy arrays, or pandas Series
#       objects passed directly to the ``x``, ``y``, and/or ``hue`` parameters.
#     - A "long-form" DataFrame, in which case the ``x``, ``y``, and ``hue``
#       variables will determine how the data are plotted.
#     - A "wide-form" DataFrame, such that each numeric column will be plotted.
# ...

# %%
data=data.dropna()
data
# Out:
#        Id  Dwell_Type  Zone_Class  LotFrontage  LotArea  Road_Type  Alley  \
# 0       1          60           3         65.0     8450          1      2
# 1       2          20           3         80.0     9600          1      2
# 2       3          60           3         68.0    11250          1      2
# 3       4          70           3         60.0     9550          1      2
# 4       5          60           3         84.0    14260          1      2
# ...   ...         ...         ...          ...      ...        ...    ...
# 2065  939          30           3         73.0     8760          1      2
# 2067  941          20           3         55.0    12640          1      2
# 2070  944          90           3        313.0    25000          1      2
# 2071  945          20           3         52.0    14375          1      2
# 2072  946          50           4         98.0     8820          1      2
#
#       Property_Shape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
plt.figure(figsize=(30,20))
columns=["Property_Shape","BedroomAbvGr","Electrical","CentralAir",
         "GarageType","Alley","Heating","SaleType",
         "SaleCondition","Foundation","KitchenQual","HouseStyle",
        "OverallQual","MasVnrType","YrSold"]
collen=len(columns)//4
if(len(columns)%4!=0):
    collen+=1
for i in range(len(columns)):
    plt.subplot(collen,4,i+1)
    sns.countplot(x=columns[i],data=data)

plt.show()

# %%
plt.figure(figsize=(30,20))

columns=["Neighborhood","RoofStyle","HouseStyle",
         "SaleCondition","Zone_Class","PavedDrive",
        "GarageType","LandSlope","Fence",
        "Fireplaces","FullBath","HalfBath"]
collen=len(columns)//3
if(len(columns)%3!=0):
    collen+=1
for i in range(len(columns)):
    plt.subplot(collen,3,i+1)
    height=data[columns[i]].value_counts()
    plt.pie(height, labels=height.index)
    plt.title(columns[i])

plt.show()

# %%
target = data["Property_Sale_Price"]
predictors = data.drop(["Id","Property_Sale_Price"], axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, random_state=123)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train, y_train)
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import r2_score
print("R2 Score:",r2_score(y_test, y_pred))
# Out:
# R2 Score: 0.7886870674579047

# %%
from sklearn.metrics import mean_squared_error as mse
print("MSE:",mse(y_test, y_pred))
# Out:
# MSE: 1219310055.4575534

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train, y_train)
y_pred2=model.predict(x_test)
# Out:
# C:\Users\Loges\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
print("R2 Score: ",r2_score(y_test, y_pred))
print("MSE: ",mse(y_test, y_pred))
# Out:
# R2 Score:  0.7886870674579047
# MSE:  1219310055.4575534
